# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df = pd.read_csv('results.csv')

# %%
df
# Out:
#      f_parallel  asic_cov  asic_alloc  asic_perf    sys_perf
# 0           100        10           1          5   96.727707
# 1           100        10           1         10  108.566378
# 2           100        10           1         50  120.350280
# 3           100        10           2          5  108.172178
# 4           100        10           2         10  115.196107
# 5           100        10           2         50  121.507996
# 6           100        10           3          5  112.755593
# 7           100        10           3         10  117.744604
# 8           100        10           3         50  122.065352
# 9           100        10           4          5  114.674999
# 10          100        10           4         10  118.505030
# 11          100        10           4         50  121.758314
# 12          100        10           5          5  115.630545
# 13          100        10           5         10  118.725858
# ...

# %%
df_f100_5x = df[(df.f_parallel == 100) & (df.asic_perf == 5)][['asic_cov','asic_alloc','sys_perf']]

# %%
df_f100_5x.plot()

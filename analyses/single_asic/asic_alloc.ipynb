# %%
import os
ANALYSIS_HOME=os.getcwd()
print(ANALYSIS_HOME)
# Out:
# /net/if10/lw2aw/projects/Lumos/lumos-dev/analyses/single_asic

# %%
import pandas as pd
import lumos.model.ptm_new.plot as plt

# %%
df = pd.read_csv(os.path.join(ANALYSIS_HOME,'results.cmos.large.csv'))
df = df.query('f_parallel==100 & asic_perf==5')[['asic_alloc','sys_perf','asic_cov']]
plt.line_plot(df, 'asic_alloc', 'sys_perf', 'asic_cov', lncols='flat')

# %%
df = pd.read_csv(os.path.join(ANALYSIS_HOME,'results.tfet.large.csv'))
df = df.query('f_parallel==100 & asic_perf==5')[['asic_alloc','sys_perf','asic_cov']]
plt.line_plot(df, 'asic_alloc', 'sys_perf', 'asic_cov',ylim=(60,200))

# %% [markdown]
# Throughput cores using TFET, system budget is small (more power-constrained)

# %%
df = pd.read_csv(os.path.join(ANALYSIS_HOME,'results.tfet.small.csv'))
df = df.query('f_parallel==100 & asic_perf==5')[['asic_alloc','sys_perf','asic_cov']]
plt.line_plot(df, 'asic_alloc', 'sys_perf', 'asic_cov')

# %% [markdown]
# Throughput cores using CMOS, system budget is small

# %%
df = pd.read_csv(os.path.join(ANALYSIS_HOME,'results.cmos.small.csv'))
df = df.query('f_parallel==100 & asic_perf==5')[['asic_alloc','sys_perf','asic_cov']]
plt.line_plot(df, 'asic_alloc', 'sys_perf', 'asic_cov')

# %%
df = pd.read_csv(os.path.join(ANALYSIS_HOME, 'results.tfet.pconstrained.csv'))
df = df.query('f_parallel==100 & asic_perf==5')[['asic_alloc','sys_perf','asic_cov']]
plt.line_plot(df, 'asic_alloc', 'sys_perf', 'asic_cov')

# %%
df = pd.read_csv(os.path.join(ANALYSIS_HOME, 'results.cmos.pconstrained.csv'))
df = df.query('f_parallel==100 & asic_perf==5')[['asic_alloc','sys_perf','asic_cov']]
plt.line_plot(df, 'asic_alloc', 'sys_perf', 'asic_cov', ylim=(50,140))

# %%
df_cmos = pd.read_csv(os.path.join(ANALYSIS_HOME, 'results.cmos.large.csv'))
df_cmos = df_cmos.query('f_parallel==100 & asic_perf==5')[['asic_alloc','sys_perf','asic_cov']]

df_tfet = pd.read_csv(os.path.join(ANALYSIS_HOME, 'results.tfet.large.csv'))
df_tfet = df_tfet.query('f_parallel==100 & asic_perf==5')[['asic_alloc','sys_perf','asic_cov']]

df_cmos['asic_cov'] = df_cmos['asic_cov'].apply(lambda x: '{0}-cmos'.format(x))
df_tfet['asic_cov'] = df_tfet['asic_cov'].apply(lambda x: '{0}-tfet'.format(x))

df = pd.concat([df_cmos, df_tfet])
df = df.query('asic_cov == "10-cmos" | asic_cov == "30-cmos" | asic_cov == "50-cmos" | asic_cov == "10-tfet" | asic_cov == "30-tfet" | asic_cov == "50-tfet"')
series = pd.Series(df['asic_cov']).unique()
